# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key



# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ariquemes
# Processing Record 2 of Set 1 | chonchi
# Processing Record 3 of Set 1 | wailua homesteads
# Processing Record 4 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 5 of Set 1 | forster
# Processing Record 6 of Set 1 | merizo village
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | zapolyarnyy
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | santa vitoria do palmar
# Processing Record 11 of Set 1 | victorica
# Processing Record 12 of Set 1 | lerwick
# Processing Record 13 of Set 1 | port-aux-francais
# Processing Record 14 of Set 1 | alexandria
# Processing Record 15 of Set 1 | grytviken
# Processing Record 16 of Set 1 | luderitz
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | mili
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | yamada
# Processing Record 22 of Set 1 | nemuro
# Processing Record 23 of Set 1 | papatowai
# Processing Record 24 of Set 1 | bad windsheim
# Processing Record 25 of Set 1 | tabou
# Processing Record 26 of Set 1 | olonkinbyen
# Processing Record 27 of Set 1 | idri
# Processing Record 28 of Set 1 | waitangi
# Processing Record 29 of Set 1 | pontes e lacerda
# Processing Record 30 of Set 1 | khagrachhari
# Processing Record 31 of Set 1 | dudinka
# Processing Record 32 of Set 1 | adamstown
# Processing Record 33 of Set 1 | edinburgh of the seven seas
# Processing Record 34 of Set 1 | aioun
# Processing Record 35 of Set 1 | carapelle
# Processing Record 36 of Set 1 | whittlesea
# Processing Record 37 of Set 1 | hasaki
# Processing Record 38 of Set 1 | novofedorivka
# Processing Record 39 of Set 1 | vorgashor
# Processing Record 40 of Set 1 | ust-nera
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | machico
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | goure
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | college
# Processing Record 47 of Set 1 | covington
# Processing Record 48 of Set 1 | ta`u
# Processing Record 49 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 50 of Set 1 | labrador city
# Processing Record 0 of Set 2 | kalmunai
# Processing Record 1 of Set 2 | robore
# Processing Record 2 of Set 2 | tsiombe
# Processing Record 3 of Set 2 | invercargill
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | fale old settlement
# Processing Record 8 of Set 2 | flying fish cove
# Processing Record 9 of Set 2 | codrington
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | hamilton
# Processing Record 12 of Set 2 | argostolion
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | mossel bay
# Processing Record 15 of Set 2 | susuman
# Processing Record 16 of Set 2 | norilsk
# Processing Record 17 of Set 2 | walvis bay
# Processing Record 18 of Set 2 | tura
# Processing Record 19 of Set 2 | sorong
# Processing Record 20 of Set 2 | sombrerete
# Processing Record 21 of Set 2 | san patricio
# Processing Record 22 of Set 2 | port lincoln
# Processing Record 23 of Set 2 | mugia
# Processing Record 24 of Set 2 | mabaruma
# Processing Record 25 of Set 2 | novodvinsk
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | nikolayevsk-on-amure
# Processing Record 28 of Set 2 | tutoia
# Processing Record 29 of Set 2 | isafjordur
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | birao
# Processing Record 32 of Set 2 | atafu village
# Processing Record 33 of Set 2 | keffi
# Processing Record 34 of Set 2 | anka
# Processing Record 35 of Set 2 | lihue
# Processing Record 36 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | puerto natales
# Processing Record 39 of Set 2 | richards bay
# Processing Record 40 of Set 2 | guerrero negro
# Processing Record 41 of Set 2 | morococha
# Processing Record 42 of Set 2 | dauphin
# Processing Record 43 of Set 2 | whitehorse
# Processing Record 44 of Set 2 | old town
# Processing Record 45 of Set 2 | caibarien
# Processing Record 46 of Set 2 | al burayqah
# Processing Record 47 of Set 2 | urzhar
# Processing Record 48 of Set 2 | belyy yar
# Processing Record 49 of Set 2 | cadale
# Processing Record 0 of Set 3 | benguela
# Processing Record 1 of Set 3 | ghormach
# Processing Record 2 of Set 3 | papao
# Processing Record 3 of Set 3 | al bawiti
# Processing Record 4 of Set 3 | fort mcmurray
# Processing Record 5 of Set 3 | margaret river
# Processing Record 6 of Set 3 | eraan
# Processing Record 7 of Set 3 | uturoa
# Processing Record 8 of Set 3 | nogliki
# Processing Record 9 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 10 of Set 3 | tvoroyri
# Processing Record 11 of Set 3 | al manshah
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 14 of Set 3 | imishli
# Processing Record 15 of Set 3 | sretensk
# Processing Record 16 of Set 3 | nuuk
# Processing Record 17 of Set 3 | albany
# Processing Record 18 of Set 3 | srivardhan
# Processing Record 19 of Set 3 | praia da vitoria
# Processing Record 20 of Set 3 | alofi
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | orange
# Processing Record 23 of Set 3 | tolanaro
# Processing Record 24 of Set 3 | challapata
# Processing Record 25 of Set 3 | garachico
# Processing Record 26 of Set 3 | tofol
# Processing Record 27 of Set 3 | meadow lakes
# Processing Record 28 of Set 3 | nueva imperial
# Processing Record 29 of Set 3 | port mathurin
# Processing Record 30 of Set 3 | wenchang
# Processing Record 31 of Set 3 | palmer
# Processing Record 32 of Set 3 | stanley
# Processing Record 33 of Set 3 | nova vicosa
# Processing Record 34 of Set 3 | barinitas
# Processing Record 35 of Set 3 | athens
# Processing Record 36 of Set 3 | merowe
# Processing Record 37 of Set 3 | knyaze-volkonskoye
# Processing Record 38 of Set 3 | oodweyne
# Processing Record 39 of Set 3 | chulym
# Processing Record 40 of Set 3 | valparaiso
# Processing Record 41 of Set 3 | crane
# Processing Record 42 of Set 3 | huocheng
# City not found. Skipping...
# Processing Record 43 of Set 3 | ndelele
# Processing Record 44 of Set 3 | glace bay
# Processing Record 45 of Set 3 | ganshui
# Processing Record 46 of Set 3 | upwey
# Processing Record 47 of Set 3 | kovdor
# Processing Record 48 of Set 3 | anadyr
# Processing Record 49 of Set 3 | saint-pierre
# Processing Record 0 of Set 4 | jamestown
# Processing Record 1 of Set 4 | vicosa
# Processing Record 2 of Set 4 | auna
# Processing Record 3 of Set 4 | aasiaat
# Processing Record 4 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 4 | dikwa
# Processing Record 6 of Set 4 | saipan
# Processing Record 7 of Set 4 | huarmey
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | dindima
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | mutuali
# Processing Record 12 of Set 4 | malvan
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | krasnyy yar
# Processing Record 15 of Set 4 | geraldton
# Processing Record 16 of Set 4 | pisco
# Processing Record 17 of Set 4 | capao bonito
# Processing Record 18 of Set 4 | port blair
# Processing Record 19 of Set 4 | sarila
# Processing Record 20 of Set 4 | taperoa
# Processing Record 21 of Set 4 | nar'yan-mar
# Processing Record 22 of Set 4 | tank
# Processing Record 23 of Set 4 | ulsteinvik
# Processing Record 24 of Set 4 | antsiranana
# Processing Record 25 of Set 4 | quirinopolis
# Processing Record 26 of Set 4 | alaghsas
# Processing Record 27 of Set 4 | badagry
# Processing Record 28 of Set 4 | tazovsky
# Processing Record 29 of Set 4 | bilibino
# Processing Record 30 of Set 4 | west island
# Processing Record 31 of Set 4 | roma
# Processing Record 32 of Set 4 | kolonia town
# Processing Record 33 of Set 4 | colonia
# Processing Record 34 of Set 4 | uniao
# Processing Record 35 of Set 4 | castillos
# Processing Record 36 of Set 4 | nouadhibou
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | acarau
# Processing Record 39 of Set 4 | blackmans bay
# Processing Record 40 of Set 4 | qaisumah
# Processing Record 41 of Set 4 | puerto deseado
# Processing Record 42 of Set 4 | keflavik
# Processing Record 43 of Set 4 | kwolla
# Processing Record 44 of Set 4 | klyuchi
# Processing Record 45 of Set 4 | porto novo
# Processing Record 46 of Set 4 | ati
# Processing Record 47 of Set 4 | ozolnieki
# Processing Record 48 of Set 4 | sao joao da barra
# Processing Record 49 of Set 4 | severo-yeniseyskiy
# Processing Record 0 of Set 5 | nabire
# Processing Record 1 of Set 5 | negombo
# Processing Record 2 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 3 of Set 5 | holualoa
# Processing Record 4 of Set 5 | mount pearl
# Processing Record 5 of Set 5 | ashland
# Processing Record 6 of Set 5 | neryungri
# Processing Record 7 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 8 of Set 5 | kodiak
# Processing Record 9 of Set 5 | borogontsy
# Processing Record 10 of Set 5 | eastham
# Processing Record 11 of Set 5 | hami
# Processing Record 12 of Set 5 | vila franca do campo
# Processing Record 13 of Set 5 | tahe
# Processing Record 14 of Set 5 | mafra
# Processing Record 15 of Set 5 | utrik
# Processing Record 16 of Set 5 | cockburn town
# Processing Record 17 of Set 5 | sitka
# Processing Record 18 of Set 5 | reggane
# Processing Record 19 of Set 5 | udachny
# Processing Record 20 of Set 5 | dryden
# Processing Record 21 of Set 5 | naldurg
# Processing Record 22 of Set 5 | quba
# Processing Record 23 of Set 5 | iskateley
# Processing Record 24 of Set 5 | dikhil
# Processing Record 25 of Set 5 | kuta
# Processing Record 26 of Set 5 | rongelap
# Processing Record 27 of Set 5 | shiyan
# Processing Record 28 of Set 5 | sima
# Processing Record 29 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 30 of Set 5 | bikenibeu village
# Processing Record 31 of Set 5 | st. john's
# Processing Record 32 of Set 5 | antofagasta
# Processing Record 33 of Set 5 | san ignacio de velasco
# Processing Record 34 of Set 5 | khovd
# Processing Record 35 of Set 5 | ghanzi
# Processing Record 36 of Set 5 | nova sintra
# Processing Record 37 of Set 5 | afaahiti
# Processing Record 38 of Set 5 | san antonio de pale
# Processing Record 39 of Set 5 | lazaro cardenas
# Processing Record 40 of Set 5 | lompoc
# Processing Record 41 of Set 5 | tocopilla
# Processing Record 42 of Set 5 | polyarnyy
# Processing Record 43 of Set 5 | ancud
# Processing Record 44 of Set 5 | sheboygan falls
# Processing Record 45 of Set 5 | san juan
# Processing Record 46 of Set 5 | hawaiian paradise park
# Processing Record 47 of Set 5 | gedo
# Processing Record 48 of Set 5 | ytrebygda
# Processing Record 49 of Set 5 | zangguy
# City not found. Skipping...
# Processing Record 0 of Set 6 | kangding
# Processing Record 1 of Set 6 | mahalapye
# Processing Record 2 of Set 6 | coquimbo
# Processing Record 3 of Set 6 | brokopondo
# Processing Record 4 of Set 6 | kuybyshev
# Processing Record 5 of Set 6 | kismayo
# Processing Record 6 of Set 6 | san andres
# Processing Record 7 of Set 6 | greymouth
# Processing Record 8 of Set 6 | takamaka
# City not found. Skipping...
# Processing Record 9 of Set 6 | mejit
# Processing Record 10 of Set 6 | shahrak-e pabedana
# City not found. Skipping...
# Processing Record 11 of Set 6 | port saint john's
# Processing Record 12 of Set 6 | greenville
# Processing Record 13 of Set 6 | katsuren-haebaru
# Processing Record 14 of Set 6 | oualidia
# City not found. Skipping...
# Processing Record 15 of Set 6 | new ulm
# Processing Record 16 of Set 6 | port alfred
# Processing Record 17 of Set 6 | juneau
# Processing Record 18 of Set 6 | tuy hoa
# Processing Record 19 of Set 6 | marsh harbour
# Processing Record 20 of Set 6 | chadan
# Processing Record 21 of Set 6 | kolonia
# Processing Record 22 of Set 6 | dunedin
# Processing Record 23 of Set 6 | sydney
# Processing Record 24 of Set 6 | coahuayana de hidalgo
# Processing Record 25 of Set 6 | pokhara
# Processing Record 26 of Set 6 | kavaratti
# Processing Record 27 of Set 6 | kailua-kona
# Processing Record 28 of Set 6 | zeribet el oued
# Processing Record 29 of Set 6 | bam
# Processing Record 30 of Set 6 | say
# Processing Record 31 of Set 6 | puerto baquerizo moreno
# Processing Record 32 of Set 6 | la'ie
# Processing Record 33 of Set 6 | constantia
# Processing Record 34 of Set 6 | cudillero
# Processing Record 35 of Set 6 | enewetak
# Processing Record 36 of Set 6 | kiunga
# Processing Record 37 of Set 6 | shira
# Processing Record 38 of Set 6 | kingston
# Processing Record 39 of Set 6 | wewak
# Processing Record 40 of Set 6 | harstad
# Processing Record 41 of Set 6 | east london
# Processing Record 42 of Set 6 | piton saint-leu
# Processing Record 43 of Set 6 | hotan
# Processing Record 44 of Set 6 | verkhnevilyuysk
# Processing Record 45 of Set 6 | constitucion
# Processing Record 46 of Set 6 | saint-denis
# Processing Record 47 of Set 6 | ketchikan
# Processing Record 48 of Set 6 | karlovo
# Processing Record 49 of Set 6 | kapuskasing
# Processing Record 0 of Set 7 | hiratacho
# Processing Record 1 of Set 7 | howrah
# Processing Record 2 of Set 7 | la ronge
# Processing Record 3 of Set 7 | manatutu
# City not found. Skipping...
# Processing Record 4 of Set 7 | argo
# Processing Record 5 of Set 7 | daru
# Processing Record 6 of Set 7 | oliver
# Processing Record 7 of Set 7 | newman
# Processing Record 8 of Set 7 | muynoq
# Processing Record 9 of Set 7 | bingol
# Processing Record 10 of Set 7 | sidrolandia
# Processing Record 11 of Set 7 | sheridan
# Processing Record 12 of Set 7 | yar
# Processing Record 13 of Set 7 | yuzhno-kurilsk
# Processing Record 14 of Set 7 | mata-utu
# Processing Record 15 of Set 7 | kingaroy
# Processing Record 16 of Set 7 | bayang
# Processing Record 17 of Set 7 | tyuratam
# Processing Record 18 of Set 7 | igarapava
# Processing Record 19 of Set 7 | revda
# Processing Record 20 of Set 7 | amalapuram
# Processing Record 21 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 22 of Set 7 | al jawf
# Processing Record 23 of Set 7 | tazacorte
# Processing Record 24 of Set 7 | fuerte olimpo
# Processing Record 25 of Set 7 | el granada
# Processing Record 26 of Set 7 | howard springs
# Processing Record 27 of Set 7 | northam
# Processing Record 28 of Set 7 | domanic
# Processing Record 29 of Set 7 | la passe
# Processing Record 30 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 31 of Set 7 | lebu
# Processing Record 32 of Set 7 | namibe
# Processing Record 33 of Set 7 | egirdir
# Processing Record 34 of Set 7 | rikaze
# Processing Record 35 of Set 7 | al ghayzah
# Processing Record 36 of Set 7 | genova
# Processing Record 37 of Set 7 | pavlovsk
# Processing Record 38 of Set 7 | prado
# Processing Record 39 of Set 7 | kurchatov
# Processing Record 40 of Set 7 | horsham
# Processing Record 41 of Set 7 | ebon
# Processing Record 42 of Set 7 | port augusta
# Processing Record 43 of Set 7 | sola
# Processing Record 44 of Set 7 | callao
# Processing Record 45 of Set 7 | susanville
# Processing Record 46 of Set 7 | ijuw
# City not found. Skipping...
# Processing Record 47 of Set 7 | maintirano
# Processing Record 48 of Set 7 | cabedelo
# Processing Record 49 of Set 7 | badger
# Processing Record 0 of Set 8 | tamanrasset
# Processing Record 1 of Set 8 | rio grande
# Processing Record 2 of Set 8 | poronaysk
# Processing Record 3 of Set 8 | hammerfest
# Processing Record 4 of Set 8 | tynda
# Processing Record 5 of Set 8 | al hadd
# Processing Record 6 of Set 8 | uliastay
# Processing Record 7 of Set 8 | bosobolo
# Processing Record 8 of Set 8 | jiexiu
# Processing Record 9 of Set 8 | kirando
# Processing Record 10 of Set 8 | tweed heads
# Processing Record 11 of Set 8 | nyurba
# Processing Record 12 of Set 8 | gebeit
# Processing Record 13 of Set 8 | pandan
# Processing Record 14 of Set 8 | ust'-ilimsk
# Processing Record 15 of Set 8 | pariaman
# Processing Record 16 of Set 8 | carolina
# Processing Record 17 of Set 8 | luwuk
# Processing Record 18 of Set 8 | lakheri
# Processing Record 19 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 20 of Set 8 | abalak
# Processing Record 21 of Set 8 | turrialba
# Processing Record 22 of Set 8 | agaro
# Processing Record 23 of Set 8 | gao
# Processing Record 24 of Set 8 | ontinyent
# Processing Record 25 of Set 8 | miri
# Processing Record 26 of Set 8 | manokwari
# Processing Record 27 of Set 8 | twon-brass
# Processing Record 28 of Set 8 | alice springs
# Processing Record 29 of Set 8 | tromso
# Processing Record 30 of Set 8 | saint-francois
# Processing Record 31 of Set 8 | alghero
# Processing Record 32 of Set 8 | asaita
# Processing Record 33 of Set 8 | las tablas
# Processing Record 34 of Set 8 | westport
# Processing Record 35 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 36 of Set 8 | vadso
# Processing Record 37 of Set 8 | kapa'a
# Processing Record 38 of Set 8 | kidal
# Processing Record 39 of Set 8 | gazojak
# Processing Record 40 of Set 8 | novaya igirma
# Processing Record 41 of Set 8 | paciran
# Processing Record 42 of Set 8 | champerico
# Processing Record 43 of Set 8 | shakiso
# Processing Record 44 of Set 8 | chinde
# Processing Record 45 of Set 8 | bereeda
# Processing Record 46 of Set 8 | cidreira
# Processing Record 47 of Set 8 | petropavl
# Processing Record 48 of Set 8 | filadelfia
# Processing Record 49 of Set 8 | luganville
# Processing Record 0 of Set 9 | aswan
# Processing Record 1 of Set 9 | lagoa santa
# Processing Record 2 of Set 9 | ilhabela
# Processing Record 3 of Set 9 | noosa heads
# Processing Record 4 of Set 9 | mosjoen
# Processing Record 5 of Set 9 | altai
# Processing Record 6 of Set 9 | santa cruz
# Processing Record 7 of Set 9 | touros
# Processing Record 8 of Set 9 | ko samui
# Processing Record 9 of Set 9 | gizo
# Processing Record 10 of Set 9 | hirara
# Processing Record 11 of Set 9 | paros
# Processing Record 12 of Set 9 | remire-montjoly
# Processing Record 13 of Set 9 | bykhaw
# Processing Record 14 of Set 9 | sarigerme
# Processing Record 15 of Set 9 | ghadamis
# Processing Record 16 of Set 9 | amungan
# Processing Record 17 of Set 9 | horta
# Processing Record 18 of Set 9 | opuwo
# Processing Record 19 of Set 9 | kerikeri
# Processing Record 20 of Set 9 | chipata
# Processing Record 21 of Set 9 | vila velha
# Processing Record 22 of Set 9 | iraquara
# Processing Record 23 of Set 9 | rantoul
# Processing Record 24 of Set 9 | kisanga
# Processing Record 25 of Set 9 | svencionys
# Processing Record 26 of Set 9 | tralee
# Processing Record 27 of Set 9 | hadibu
# Processing Record 28 of Set 9 | sisimiut
# Processing Record 29 of Set 9 | puerto maldonado
# Processing Record 30 of Set 9 | batticaloa
# Processing Record 31 of Set 9 | tozeur
# Processing Record 32 of Set 9 | alesund
# Processing Record 33 of Set 9 | mount gambier
# Processing Record 34 of Set 9 | nieuw amsterdam
# Processing Record 35 of Set 9 | muroran
# Processing Record 36 of Set 9 | general roca
# Processing Record 37 of Set 9 | murzuq
# Processing Record 38 of Set 9 | jawf al maqbabah
# Processing Record 39 of Set 9 | la sarre
# Processing Record 40 of Set 9 | cambria
# Processing Record 41 of Set 9 | arraial do cabo
# Processing Record 42 of Set 9 | kodinsk
# Processing Record 43 of Set 9 | sinabang
# Processing Record 44 of Set 9 | timmins
# Processing Record 45 of Set 9 | quellon
# Processing Record 46 of Set 9 | ocean pointe
# City not found. Skipping...
# Processing Record 47 of Set 9 | fort bragg
# Processing Record 48 of Set 9 | voronovytsya
# Processing Record 49 of Set 9 | yeppoon
# Processing Record 0 of Set 10 | ibiza
# Processing Record 1 of Set 10 | lautoka
# Processing Record 2 of Set 10 | sechura
# Processing Record 3 of Set 10 | okhotsk
# Processing Record 4 of Set 10 | male
# Processing Record 5 of Set 10 | nago
# Processing Record 6 of Set 10 | payette
# Processing Record 7 of Set 10 | nkurenkuru
# City not found. Skipping...
# Processing Record 8 of Set 10 | mar del plata
# Processing Record 9 of Set 10 | gaogou
# Processing Record 10 of Set 10 | puerto leguizamo
# Processing Record 11 of Set 10 | aykhal
# Processing Record 12 of Set 10 | verkhniye kigi
# Processing Record 13 of Set 10 | natal
# Processing Record 14 of Set 10 | chos malal
# Processing Record 15 of Set 10 | gumdag
# Processing Record 16 of Set 10 | dese
# Processing Record 17 of Set 10 | socorro
# Processing Record 18 of Set 10 | kavieng
# Processing Record 19 of Set 10 | brookings
# Processing Record 20 of Set 10 | sur
# Processing Record 21 of Set 10 | xining
# Processing Record 22 of Set 10 | wanning
# Processing Record 23 of Set 10 | mantua
# Processing Record 24 of Set 10 | tecozautla
# Processing Record 25 of Set 10 | mandal
# Processing Record 26 of Set 10 | bukittinggi
# Processing Record 27 of Set 10 | tantou
# Processing Record 28 of Set 10 | davlekanovo
# Processing Record 29 of Set 10 | mezhdurechenskiy
# Processing Record 30 of Set 10 | santa rita
# Processing Record 31 of Set 10 | banki
# Processing Record 32 of Set 10 | al qadarif
# Processing Record 33 of Set 10 | tarija
# Processing Record 34 of Set 10 | laguna
# Processing Record 35 of Set 10 | tokar
# Processing Record 36 of Set 10 | yaren
# Processing Record 37 of Set 10 | dalandzadgad
# Processing Record 38 of Set 10 | slave lake
# Processing Record 39 of Set 10 | pattaya
# Processing Record 40 of Set 10 | guatire
# Processing Record 41 of Set 10 | hakui
# Processing Record 42 of Set 10 | oak hill
# Processing Record 43 of Set 10 | greenland
# Processing Record 44 of Set 10 | litvinov
# Processing Record 45 of Set 10 | udgir
# Processing Record 46 of Set 10 | callaway
# Processing Record 47 of Set 10 | mahdia
# Processing Record 48 of Set 10 | bairnsdale
# Processing Record 49 of Set 10 | laojunmiao
# Processing Record 0 of Set 11 | port douglas
# Processing Record 1 of Set 11 | barra de santo antonio
# Processing Record 2 of Set 11 | kununurra
# Processing Record 3 of Set 11 | krasnyy chikoy
# Processing Record 4 of Set 11 | priolo gargallo
# Processing Record 5 of Set 11 | broome
# Processing Record 6 of Set 11 | sao vicente
# Processing Record 7 of Set 11 | childress
# Processing Record 8 of Set 11 | porbandar
# Processing Record 9 of Set 11 | vilyuchinsk
# Processing Record 10 of Set 11 | aripuana
# Processing Record 11 of Set 11 | beihai
# Processing Record 12 of Set 11 | al faw
# Processing Record 13 of Set 11 | qaqortoq
# Processing Record 14 of Set 11 | bumba
# Processing Record 15 of Set 11 | tobi village
# City not found. Skipping...
# Processing Record 16 of Set 11 | san martin
# Processing Record 17 of Set 11 | el calafate
# Processing Record 18 of Set 11 | nuku'alofa
# Processing Record 19 of Set 11 | nema
# Processing Record 20 of Set 11 | kruisfontein
# Processing Record 21 of Set 11 | la banda
# Processing Record 22 of Set 11 | una
# Processing Record 23 of Set 11 | flin flon
# Processing Record 24 of Set 11 | egilsstadir
# Processing Record 25 of Set 11 | colares
# Processing Record 26 of Set 11 | usinsk
# Processing Record 27 of Set 11 | vernon
# Processing Record 28 of Set 11 | boa vista
# Processing Record 29 of Set 11 | asbury lake
# Processing Record 30 of Set 11 | tadine
# Processing Record 31 of Set 11 | cabo san lucas
# Processing Record 32 of Set 11 | kokemaki
# Processing Record 33 of Set 11 | jasper
# Processing Record 34 of Set 11 | itaituba
# Processing Record 35 of Set 11 | novo aripuana
# Processing Record 36 of Set 11 | les cayes
# Processing Record 37 of Set 11 | musay'id
# City not found. Skipping...
# Processing Record 38 of Set 11 | kabalo
# Processing Record 39 of Set 11 | shingu
# Processing Record 40 of Set 11 | calabar
# Processing Record 41 of Set 11 | roxas
# Processing Record 42 of Set 11 | whakatane
# Processing Record 43 of Set 11 | ushtobe
# Processing Record 44 of Set 11 | tieli
# Processing Record 45 of Set 11 | patacamaya
# Processing Record 46 of Set 11 | calama
# Processing Record 47 of Set 11 | nyzhni sirohozy
# Processing Record 48 of Set 11 | xiahu
# Processing Record 49 of Set 11 | ulysses
# Processing Record 0 of Set 12 | koidu
# Processing Record 1 of Set 12 | cameron
# Processing Record 2 of Set 12 | ixtlan del rio
# Processing Record 3 of Set 12 | jagannathpur
# Processing Record 4 of Set 12 | temiskaming shores
# Processing Record 5 of Set 12 | manapparai
# Processing Record 6 of Set 12 | vilyuysk
# Processing Record 7 of Set 12 | ardestan
# Processing Record 8 of Set 12 | shushtar
# Processing Record 9 of Set 12 | korla
# Processing Record 10 of Set 12 | kapit
# Processing Record 11 of Set 12 | lamu
# Processing Record 12 of Set 12 | biala podlaska
# Processing Record 13 of Set 12 | adamovka
# Processing Record 14 of Set 12 | albesti
# Processing Record 15 of Set 12 | haiku-pauwela
# Processing Record 16 of Set 12 | isoka
# Processing Record 17 of Set 12 | macheng
# Processing Record 18 of Set 12 | ouarzazat
# Processing Record 19 of Set 12 | zhosaly
# Processing Record 20 of Set 12 | naze
# Processing Record 21 of Set 12 | mezgor'e
# City not found. Skipping...
# Processing Record 22 of Set 12 | teloloapan
# Processing Record 23 of Set 12 | nowrangapur
# City not found. Skipping...
# Processing Record 24 of Set 12 | sao gotardo
# Processing Record 25 of Set 12 | peschanokopskoye
# Processing Record 26 of Set 12 | kishapu
# Processing Record 27 of Set 12 | tateyama
# Processing Record 28 of Set 12 | bayanaul
# Processing Record 29 of Set 12 | princeton
# Processing Record 30 of Set 12 | lagos
# Processing Record 31 of Set 12 | sarkand
# Processing Record 32 of Set 12 | mascoutah
# Processing Record 33 of Set 12 | zhanjiang
# Processing Record 34 of Set 12 | richmond
# Processing Record 35 of Set 12 | los frentones
# Processing Record 36 of Set 12 | sao jose da coroa grande
# Processing Record 37 of Set 12 | adh dhibiyah
# City not found. Skipping...
# Processing Record 38 of Set 12 | feicheng
# Processing Record 39 of Set 12 | bijie
# Processing Record 40 of Set 12 | dainville
# Processing Record 41 of Set 12 | lambarene
# Processing Record 42 of Set 12 | posto fiscal rolim de moura
# Processing Record 43 of Set 12 | marabba
# Processing Record 44 of Set 12 | tosontsengel
# Processing Record 45 of Set 12 | tangstedt
# Processing Record 46 of Set 12 | vallenar
# Processing Record 47 of Set 12 | valdivia
# Processing Record 48 of Set 12 | cable beach
# City not found. Skipping...
# Processing Record 49 of Set 12 | toliara
# Processing Record 0 of Set 13 | bichena
# Processing Record 1 of Set 13 | letlhakeng
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          575
# Lat           575
# Lng           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          ariquemes  -9.9133  -63.0408     76.77        95          99
# 1            chonchi -42.6128  -73.8092     62.31        69          11
# 2  wailua homesteads  22.0669 -159.3780     79.23        78          40
# 3            forster -32.1667  152.5167     74.37        79          88
# 4     merizo village  13.2658  144.6691     82.96        79          99
#
#    Wind Speed Country        Date
# 0        3.27      BR  1707606852
# 1        1.10      CL  1707606852
# 2        6.91      US  1707606852
# 3       12.21      AU  1707606853
# 4       18.68      GU  1707606853

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                ariquemes  -9.9133  -63.0408     76.77        95          99
# 1                  chonchi -42.6128  -73.8092     62.31        69          11
# 2        wailua homesteads  22.0669 -159.3780     79.23        78          40
# 3                  forster -32.1667  152.5167     74.37        79          88
# 4           merizo village  13.2658  144.6691     82.96        79          99
#
#          Wind Speed Country        Date
# City_ID
# 0              3.27      BR  1707606852
# 1              1.10      CL  1707606852
# 2              6.91      US  1707606852
# 3             12.21      AU  1707606853
# 4             18.68      GU  1707606853

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], 
            city_data_df["Max Temp"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], 
            city_data_df["Humidity"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], 
            city_data_df["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], 
            city_data_df["Wind Speed"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        wailua homesteads  22.0669 -159.3780     79.23        78          40
# 4           merizo village  13.2658  144.6691     82.96        79          99
# 5                  talnakh  69.4865   88.3972    -17.93        87          97
# 6              zapolyarnyy  69.4154   30.8136     -2.92        88         100
# 7               georgetown   5.4112  100.3354     80.53        65          20
#
#          Wind Speed Country        Date
# City_ID
# 2              6.91      US  1707606852
# 4             18.68      GU  1707606853
# 5              3.24      RU  1707606853
# 6              6.24      RU  1707606854
# 7              6.91      MY  1707606854

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                             City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      ariquemes  -9.9133  -63.0408     76.77        95
# 1                        chonchi -42.6128  -73.8092     62.31        69
# 3                        forster -32.1667  152.5167     74.37        79
# 8        santa vitoria do palmar -33.5189  -53.3681     73.89        96
# 9                      victorica -36.2151  -65.4359     82.47        49
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                99        3.27      BR  1707606852
# 1                11        1.10      CL  1707606852
# 3                88       12.21      AU  1707606853
# 8               100       15.41      BR  1707606572
# 9                 6        5.03      AR  1707606855

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
#Temperature vs. Latitude Linear Regression PlotLinear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

# %%
# Temperature vs. Latitude Linear Regression Plot on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere - Max Temp vs. Latitude Linear Regression')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
#Humidity vs. Latitude Linear Regression Plot Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere - Humidity vs. Latitude Linear Regression')

# %%
# Humidity vs. Latitude Linear Regression Plot Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere - Humidity vs. Latitude Linear Regression')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
#Cloudiness vs. Latitude Linear Regression Plot Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')

# %%
#Cloudiness vs. Latitude Linear Regression Plot Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Wind Speed vs. Latitude Linear Regression PlotNorthern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')

# %%
# Wind Speed vs. Latitude Linear Regression Plot Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
